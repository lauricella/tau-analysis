# %%
import plumed
import matplotlib.pyplot as plt
import os
import subprocess

# %%
import MDAnalysis

# %%
import numpy as np
import math

# %%
ls
# Out:
# align.sh*                 fes_154.dat  fes_5.dat
# analisi.trimer.b2.ipynb   fes_155.dat  fes_60.dat
# COLVAR_reweighted         fes_156.dat  fes_61.dat
# COLVAR_reweighted1.0-2.0  fes_157.dat  fes_62.dat
# COLVAR_reweighted2.0-3.0  fes_158.dat  fes_63.dat
# fes_0.dat                 fes_159.dat  fes_64.dat
# fes_100.dat               fes_15.dat   fes_65.dat
# fes_101.dat               fes_160.dat  fes_66.dat
# fes_102.dat               fes_161.dat  fes_67.dat
# fes_103.dat               fes_162.dat  fes_68.dat
# fes_104.dat               fes_163.dat  fes_69.dat
# fes_105.dat               fes_164.dat  fes_6.dat
# fes_106.dat               fes_165.dat  fes_70.dat
# fes_107.dat               fes_166.dat  fes_71.dat
# fes_108.dat               fes_167.dat  fes_72.dat
# fes_109.dat               fes_168.dat  fes_73.dat
# fes_10.dat                fes_169.dat  fes_74.dat
# fes_110.dat               fes_16.dat   fes_75.dat
# fes_111.dat               fes_17.dat   fes_76.dat
# fes_112.dat               fes_18.dat   fes_77.dat
# fes_113.dat               fes_19.dat   fes_78.dat
# fes_114.dat               fes_1.dat    fes_79.dat
# fes_115.dat               fes_20.dat   fes_7.dat
# fes_116.dat               fes_21.dat   fes_80.dat
# fes_117.dat               fes_22.dat   fes_81.dat
# fes_118.dat               fes_23.dat   fes_82.dat
# fes_119.dat               fes_24.dat   fes_83.dat
# fes_11.dat                fes_25.dat   fes_84.dat
# fes_120.dat               fes_26.dat   fes_85.dat
# fes_121.dat               fes_27.dat   fes_86.dat
# fes_122.dat               fes_28.dat   fes_87.dat
# fes_123.dat               fes_29.dat   fes_88.dat
# fes_124.dat               fes_2.dat    fes_89.dat
# fes_125.dat               fes_30.dat   fes_8.dat
# fes_126.dat               fes_31.dat   fes_90.dat
# fes_127.dat               fes_32.dat   fes_91.dat
# fes_128.dat               fes_33.dat   fes_92.dat
# fes_129.dat               fes_34.dat   fes_93.dat
# fes_12.dat                fes_35.dat   fes_94.dat
# fes_130.dat               fes_36.dat   fes_95.dat
# fes_131.dat               fes_37.dat   fes_96.dat
# fes_132.dat               fes_38.dat   fes_97.dat
# fes_133.dat               fes_39.dat   fes_98.dat
# fes_134.dat               fes_3.dat    fes_99.dat
# fes_135.dat               fes_40.dat   fes_9.dat
# fes_136.dat               fes_41.dat   ffrmsda_reweighted1.0-2.0.dat
# fes_137.dat               fes_42.dat   ffrmsda_reweighted2.0-3.0.dat
# fes_138.dat               fes_43.dat   ffrmsda_reweighted.dat
# fes_139.dat               fes_44.dat   HILLS
# fes_13.dat                fes_45.dat   HILLS1.0-2.0
# fes_140.dat               fes_46.dat   HILLS2.0-3.0
# fes_141.dat               fes_47.dat   inizio_select.gro
# fes_142.dat               fes_48.dat   plumed.dat
# fes_143.dat               fes_49.dat   plumed_rew1.0-2.0.dat
# fes_144.dat               fes_4.dat    plumed_rew2.0-3.0.dat
# fes_145.dat               fes_50.dat   plumed_rew.dat
# fes_146.dat               fes_51.dat   prot_ref_a.pdb
# fes_147.dat               fes_52.dat   prot_ref_b.pdb
# fes_148.dat               fes_53.dat   prot_ref_c.pdb
# fes_149.dat               fes_54.dat   traj1.0-2.0.xtc
# fes_14.dat                fes_55.dat   traj2.0-3.0.xtc
# fes_150.dat               fes_56.dat   traj_comp_align.xtc
# fes_151.dat               fes_57.dat   traj_comp_unwrap.xtc@
# fes_152.dat               fes_58.dat
# fes_153.dat               fes_59.dat

# %%
miadir=os.getcwd()

# %%
print (miadir)
# Out:
# /hdnas/marcol/tau/polimeri-120/trimer/CV-meta4/select-new

# %%
# %%bash
# pwd
# Out:
# /hdnas/marcol/tau/polimeri-120/trimer/CV-meta4/select-new

# %%
# !pwd
# Out:
# /hdnas/marcol/tau/polimeri-120/trimer/CV-meta4/select-new

# %%
# %%bash
# plumed sum_hills --hills HILLS --stride 20000 --mintozero
# Out:
# PLUMED: PLUMED is starting
# PLUMED: Version: 2.9.0 (git: Unknown) compiled on Jun 18 2023 at 17:13:44
# PLUMED: Please cite these papers when using PLUMED [1][2]
# PLUMED: For further information see the PLUMED web page at http://www.plumed.org
# PLUMED: Root: /opt/plumed-2.9.0/lib/plumed
# PLUMED: For installed feature, see /opt/plumed-2.9.0/lib/plumed/src/config/config.txt
# PLUMED: Molecular dynamics engine:
# PLUMED: Precision of reals: 8
# PLUMED: Running over 1 node
# PLUMED: Number of threads: 1
# PLUMED: Cache line size: 512
# PLUMED: Number of atoms: 1
# PLUMED: File suffix:
# PLUMED: Timestep: 0.000000
# PLUMED: KbT has not been set by the MD engine
# PLUMED: It should be set by hand where needed
# PLUMED: Relevant bibliography:
# PLUMED:   [1] The PLUMED consortium, Nat. Methods 16, 670 (2019)
# PLUMED:   [2] Tribello, Bonomi, Branduardi, Camilloni, and Bussi, Comput. Phys. Commun. 185, 604 (2014)
# PLUMED: Please read and cite where appropriate!
# PLUMED: Finished setup
# PLUMED: Action FAKE
# PLUMED:   with label sumrmsdint
# PLUMED: Action FUNCSUMHILLS
# PLUMED:   with label @1
# PLUMED:   with arguments sumrmsdint
# PLUMED:   Output format is %14.9f
# PLUMED:   hillsfile  : HILLS
# PLUMED:
# PLUMED:   No boundaries defined: need to do a prescreening of hills
# PLUMED:   doing serialread
# PLUMED:   opening file HILLS
# PLUMED:   closing file HILLS
# PLUMED:   now total 3392000 kernels
# PLUMED:   final chunk: now with 3392000 kernels
# PLUMED:   found boundaries from hillsfile:
# PLUMED:   variable sumrmsdint min: 1.03105 max: 4.76942 nbin: 212
# PLUMED:   done!
# PLUMED:
# PLUMED:   Doing integration slices every 20000 kernels
# PLUMED:   mintozero: bias/histogram will be translated to have the minimum value equal to zero
# PLUMED:   output file for fes/bias  is :  fes_
# PLUMED:
# PLUMED:   Now calculating...
# PLUMED:
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   opening file HILLS
# PLUMED:   done with this chunk: now with 20000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_0.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 40000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_1.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 60000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_2.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 80000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_3.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 100000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_4.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 120000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_5.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 140000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_6.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 160000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_7.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 180000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_8.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 200000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_9.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 220000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_10.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 240000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_11.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 260000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_12.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 280000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_13.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 300000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_14.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 320000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_15.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 340000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_16.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 360000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_17.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 380000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_18.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 400000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_19.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 420000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_20.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 440000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_21.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 460000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_22.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 480000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_23.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 500000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_24.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 520000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_25.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 540000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_26.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 560000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_27.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 580000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_28.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 600000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_29.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 620000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_30.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 640000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_31.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 660000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_32.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 680000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_33.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 700000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_34.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 720000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_35.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 740000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_36.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 760000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_37.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 780000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_38.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 800000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_39.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 820000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_40.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 840000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_41.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 860000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_42.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 880000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_43.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 900000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_44.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 920000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_45.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 940000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_46.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 960000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_47.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 980000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_48.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1000000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_49.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1020000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_50.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1040000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_51.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1060000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_52.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1080000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_53.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1100000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_54.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1120000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_55.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1140000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_56.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1160000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_57.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1180000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_58.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1200000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_59.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1220000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_60.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1240000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_61.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1260000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_62.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1280000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_63.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1300000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_64.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1320000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_65.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1340000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_66.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1360000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_67.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1380000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_68.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1400000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_69.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1420000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_70.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1440000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_71.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1460000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_72.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1480000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_73.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1500000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_74.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1520000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_75.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1540000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_76.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1560000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_77.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1580000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_78.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1600000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_79.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1620000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_80.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1640000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_81.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1660000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_82.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1680000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_83.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1700000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_84.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1720000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_85.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1740000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_86.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1760000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_87.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1780000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_88.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1800000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_89.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1820000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_90.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1840000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_91.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1860000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_92.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1880000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_93.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1900000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_94.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1920000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_95.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1940000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_96.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1960000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_97.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 1980000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_98.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2000000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_99.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2020000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_100.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2040000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_101.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2060000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_102.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2080000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_103.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2100000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_104.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2120000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_105.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2140000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_106.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2160000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_107.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2180000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_108.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2200000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_109.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2220000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_110.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2240000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_111.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2260000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_112.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2280000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_113.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2300000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_114.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2320000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_115.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2340000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_116.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2360000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_117.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2380000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_118.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2400000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_119.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2420000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_120.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2440000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_121.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2460000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_122.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2480000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_123.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2500000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_124.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2520000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_125.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2540000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_126.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2560000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_127.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2580000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_128.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2600000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_129.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2620000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_130.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2640000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_131.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2660000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_132.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2680000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_133.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2700000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_134.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2720000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_135.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2740000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_136.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2760000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_137.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2780000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_138.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2800000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_139.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2820000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_140.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2840000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_141.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2860000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_142.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2880000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_143.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2900000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_144.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2920000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_145.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2940000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_146.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2960000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_147.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 2980000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_148.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 3000000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_149.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 3020000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_150.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 3040000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_151.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 3060000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_152.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 3080000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_153.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 3100000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_154.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 3120000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_155.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 3140000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_156.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 3160000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_157.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 3180000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_158.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 3200000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_159.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 3220000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_160.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 3240000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_161.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 3260000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_162.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 3280000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_163.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 3300000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_164.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 3320000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_165.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 3340000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_166.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 3360000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_167.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   done with this chunk: now with 3380000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_168.dat
# PLUMED:   reading hills:
# PLUMED:   doing serialread
# PLUMED:   closing file HILLS
# PLUMED:   now total 3392000 kernels
# PLUMED:   final chunk: now with 3392000 kernels
# PLUMED:
# PLUMED:   Writing full grid on file fes_169.dat
# PLUMED:                                               Cycles        Total      Average      Minimum      Maximum
# PLUMED: 0 Summing hills                                    1    92.756526    92.756526    92.756526    92.756526
# PLUMED:                                               Cycles        Total      Average      Minimum      Maximum
# PLUMED:                                                    1     0.000406     0.000406     0.000406     0.000406

# %%
plt.figure(figsize=(10,6))
for i in range(150,170,1):

    data=plumed.read_as_pandas("fes_"+str(i)+".dat")
    plt.plot(data["sumrmsdint"],data["file.free"], label="Ng="+str(int(i/1))+"k")

plt.xlabel("sumrmsdint [nm]")
plt.ylabel("free energy [kJ/mol]")
plt.legend(ncol=2)

# %%
plt.figure(figsize=(10,6))
for i in range(150,170,1):

    data=plumed.read_as_pandas("fes_"+str(i)+".dat")
    plt.plot(data["sumrmsdint"]/3,data["file.free"], label="Ng="+str(int(i/1))+"k")

plt.xlabel("sumrmsdint per chain [nm]")
plt.ylabel("free energy [kJ/mol]")
plt.legend(ncol=2)

# %%
data_hills=plumed.read_as_pandas("HILLS")

# %%
plt.figure(figsize=(10,6))
plt.xlabel("time [ns]")
plt.ylabel("sumrmsdint [nm]")
plt.plot(data_hills["time"]/1000.0,data_hills["sumrmsdint"],label="HILLS")
plt.legend()

# %%
# %%bash
# cat > "plumed_rew.dat" << EOF
# rmsda: RMSD REFERENCE=prot_ref_a.pdb TYPE=OPTIMAL
# rmsdb: RMSD REFERENCE=prot_ref_b.pdb TYPE=OPTIMAL
# rmsdc: RMSD REFERENCE=prot_ref_c.pdb TYPE=OPTIMAL
# sumrmsdint: CUSTOM ARG=rmsda,rmsdb,rmsdc VAR=ax,bx,cx FUNC=sqrt(ax*ax+bx*bx+cx*cx) PERIODIC=NO
#
# metad: METAD ARG=sumrmsdint ...
# PACE=10000000 HEIGHT=0.0 SIGMA=0.05 FILE=HILLS GRID_MIN=0.0 GRID_MAX=17.0 BIASFACTOR=2.0 TEMP=310.0
# RESTART=YES # <- this is the new stuff!
# ...
#
# # Use the metadynamics bias as argument
# as: REWEIGHT_BIAS ARG=metad.bias
# # Calculate histograms of phi and psi dihedrals every 50 steps
# # using the weights obtained from the metadynamics bias potentials (umbrella-sampling-like reweighting)
# # Look at the manual to understand the parameters of the HISTOGRAM action!
# hhrmsda: HISTOGRAM ARG=sumrmsdint STRIDE=1 GRID_MIN=0.0 GRID_MAX=17.0 GRID_BIN=340 BANDWIDTH=0.05 LOGWEIGHTS=as
# # Convert histograms h(s) to free energies F(s) = -kBT * log(h(s))
# ffrmsda: CONVERT_TO_FES GRID=hhrmsda
# # Print out the free energies F(s) to file once the entire trajectory is processed
# DUMPGRID GRID=ffrmsda FILE=ffrmsda_reweighted.dat
#
# PRINT ARG=sumrmsdint,metad.bias FILE=COLVAR_reweighted STRIDE=1 # <- also change this one!
# EOF

# %%
'''
plumed driver --ixtc traj_comp_align.xtc --plumed plumed_rew.dat --kt 2.57748341158 --timestep 10.0
'''
# Out:
# '\nplumed driver --ixtc traj_comp_align.xtc --plumed plumed_rew.dat --kt 2.57748341158 --timestep 10.0\n'

# %%
# %%bash
# plumed driver --ixtc traj_comp_align.xtc --plumed plumed_rew.dat --kt 2.57748341158 --timestep 10.0
# Out:
# PLUMED: PLUMED is starting
# PLUMED: Version: 2.9.0 (git: Unknown) compiled on Jun 18 2023 at 17:13:44
# PLUMED: Please cite these papers when using PLUMED [1][2]
# PLUMED: For further information see the PLUMED web page at http://www.plumed.org
# PLUMED: Root: /opt/plumed-2.9.0/lib/plumed
# PLUMED: For installed feature, see /opt/plumed-2.9.0/lib/plumed/src/config/config.txt
# PLUMED: Molecular dynamics engine: driver
# PLUMED: Precision of reals: 8
# PLUMED: Running over 1 node
# PLUMED: Number of threads: 1
# PLUMED: Cache line size: 512
# PLUMED: Number of atoms: 3591
# PLUMED: File suffix:
# PLUMED: FILE: plumed_rew.dat
# PLUMED: Action RMSD
# PLUMED:   with label rmsda
# PLUMED:   reference from file prot_ref_a.pdb
# PLUMED:   which contains 307 atoms
# PLUMED:   with indices :
# PLUMED: 1 5 8 9 10 12 19 20 21 23 35 36 37 39 52 53 54 56 71 72 73 75 87 88 89
# PLUMED: 91 108 109 110 112 130 131 132 136 144 145 146 148 160 161 162 164 172 173 174 176 191 192 193 195
# PLUMED: 202 203 204 206 224 225 226 228 240 241 242 244 254 255 256 258 265 266 267 269 287 288 289 291 298
# PLUMED: 299 300 302 305 306 307 309 316 317 318 320 335 336 337 339 342 343 344 346 356 357 358 360 375 376
# PLUMED: 377 379 392 393 394 396 409 410 411 413 431 432 433 437 445 446 447 449 452 453 454 456 459 460 461
# PLUMED: 463 466 467 468 470 483 484 485 487 499 500 501 503 514 515 516 518 530 531 532 534 552 553 554 556
# PLUMED: 563 564 565 567 578 579 580 582 600 601 602 604 619 620 621 623 631 632 633 635 651 652 653 655 673
# PLUMED: 674 675 677 685 686 687 689 709 710 711 713 725 726 727 729 742 743 744 746 753 754 755 757 775 776
# PLUMED: 777 779 794 795 796 798 801 802 803 805 812 813 814 816 831 832 833 835 843 844 845 847 857 858 859
# PLUMED: 861 876 877 878 880 890 891 892 894 907 908 909 911 923 924 925 929 937 938 939 941 944 945 946 948
# PLUMED: 951 952 953 955 958 959 960 962 972 973 974 976 994 995 996 998 1016 1017 1018 1020 1035 1036 1037 1039 1050
# PLUMED: 1051 1052 1054 1064 1065 1066 1068 1081 1082 1083 1085 1103 1104 1105 1107 1122 1123 1124 1126 1136 1137 1138 1140 1156 1157
# PLUMED: 1158 1160 1180 1181 1182 1184 1195
# PLUMED:   method for alignment : OPTIMAL
# PLUMED:   using periodic boundary conditions
# PLUMED: Action RMSD
# PLUMED:   with label rmsdb
# PLUMED:   reference from file prot_ref_b.pdb
# PLUMED:   which contains 307 atoms
# PLUMED:   with indices :
# PLUMED: 1198 1202 1205 1206 1207 1209 1216 1217 1218 1220 1232 1233 1234 1236 1249 1250 1251 1253 1268 1269 1270 1272 1284 1285 1286
# PLUMED: 1288 1305 1306 1307 1309 1327 1328 1329 1333 1341 1342 1343 1345 1357 1358 1359 1361 1369 1370 1371 1373 1388 1389 1390 1392
# PLUMED: 1399 1400 1401 1403 1421 1422 1423 1425 1437 1438 1439 1441 1451 1452 1453 1455 1462 1463 1464 1466 1484 1485 1486 1488 1495
# PLUMED: 1496 1497 1499 1502 1503 1504 1506 1513 1514 1515 1517 1532 1533 1534 1536 1539 1540 1541 1543 1553 1554 1555 1557 1572 1573
# PLUMED: 1574 1576 1589 1590 1591 1593 1606 1607 1608 1610 1628 1629 1630 1634 1642 1643 1644 1646 1649 1650 1651 1653 1656 1657 1658
# PLUMED: 1660 1663 1664 1665 1667 1680 1681 1682 1684 1696 1697 1698 1700 1711 1712 1713 1715 1727 1728 1729 1731 1749 1750 1751 1753
# PLUMED: 1760 1761 1762 1764 1775 1776 1777 1779 1797 1798 1799 1801 1816 1817 1818 1820 1828 1829 1830 1832 1848 1849 1850 1852 1870
# PLUMED: 1871 1872 1874 1882 1883 1884 1886 1906 1907 1908 1910 1922 1923 1924 1926 1939 1940 1941 1943 1950 1951 1952 1954 1972 1973
# PLUMED: 1974 1976 1991 1992 1993 1995 1998 1999 2000 2002 2009 2010 2011 2013 2028 2029 2030 2032 2040 2041 2042 2044 2054 2055 2056
# PLUMED: 2058 2073 2074 2075 2077 2087 2088 2089 2091 2104 2105 2106 2108 2120 2121 2122 2126 2134 2135 2136 2138 2141 2142 2143 2145
# PLUMED: 2148 2149 2150 2152 2155 2156 2157 2159 2169 2170 2171 2173 2191 2192 2193 2195 2213 2214 2215 2217 2232 2233 2234 2236 2247
# PLUMED: 2248 2249 2251 2261 2262 2263 2265 2278 2279 2280 2282 2300 2301 2302 2304 2319 2320 2321 2323 2333 2334 2335 2337 2353 2354
# PLUMED: 2355 2357 2377 2378 2379 2381 2392
# PLUMED:   method for alignment : OPTIMAL
# PLUMED:   using periodic boundary conditions
# PLUMED: Action RMSD
# PLUMED:   with label rmsdc
# PLUMED:   reference from file prot_ref_c.pdb
# PLUMED:   which contains 307 atoms
# PLUMED:   with indices :
# PLUMED: 2395 2399 2402 2403 2404 2406 2413 2414 2415 2417 2429 2430 2431 2433 2446 2447 2448 2450 2465 2466 2467 2469 2481 2482 2483
# PLUMED: 2485 2502 2503 2504 2506 2524 2525 2526 2530 2538 2539 2540 2542 2554 2555 2556 2558 2566 2567 2568 2570 2585 2586 2587 2589
# PLUMED: 2596 2597 2598 2600 2618 2619 2620 2622 2634 2635 2636 2638 2648 2649 2650 2652 2659 2660 2661 2663 2681 2682 2683 2685 2692
# PLUMED: 2693 2694 2696 2699 2700 2701 2703 2710 2711 2712 2714 2729 2730 2731 2733 2736 2737 2738 2740 2750 2751 2752 2754 2769 2770
# PLUMED: 2771 2773 2786 2787 2788 2790 2803 2804 2805 2807 2825 2826 2827 2831 2839 2840 2841 2843 2846 2847 2848 2850 2853 2854 2855
# PLUMED: 2857 2860 2861 2862 2864 2877 2878 2879 2881 2893 2894 2895 2897 2908 2909 2910 2912 2924 2925 2926 2928 2946 2947 2948 2950
# PLUMED: 2957 2958 2959 2961 2972 2973 2974 2976 2994 2995 2996 2998 3013 3014 3015 3017 3025 3026 3027 3029 3045 3046 3047 3049 3067
# PLUMED: 3068 3069 3071 3079 3080 3081 3083 3103 3104 3105 3107 3119 3120 3121 3123 3136 3137 3138 3140 3147 3148 3149 3151 3169 3170
# PLUMED: 3171 3173 3188 3189 3190 3192 3195 3196 3197 3199 3206 3207 3208 3210 3225 3226 3227 3229 3237 3238 3239 3241 3251 3252 3253
# PLUMED: 3255 3270 3271 3272 3274 3284 3285 3286 3288 3301 3302 3303 3305 3317 3318 3319 3323 3331 3332 3333 3335 3338 3339 3340 3342
# PLUMED: 3345 3346 3347 3349 3352 3353 3354 3356 3366 3367 3368 3370 3388 3389 3390 3392 3410 3411 3412 3414 3429 3430 3431 3433 3444
# PLUMED: 3445 3446 3448 3458 3459 3460 3462 3475 3476 3477 3479 3497 3498 3499 3501 3516 3517 3518 3520 3530 3531 3532 3534 3550 3551
# PLUMED: 3552 3554 3574 3575 3576 3578 3589
# PLUMED:   method for alignment : OPTIMAL
# PLUMED:   using periodic boundary conditions
# PLUMED: Action CUSTOM
# PLUMED:   with label sumrmsdint
# PLUMED:   with arguments rmsda rmsdb rmsdc
# PLUMED:   with function : sqrt(ax*ax+bx*bx+cx*cx)
# PLUMED:   with variables : ax bx cx
# PLUMED:   function as parsed by lepton: sqrt(((square(ax))+(square(bx)))+(square(cx)))
# PLUMED:   derivatives as computed by lepton:
# PLUMED:     (0.5*(recip(sqrt(((square(ax))+(square(bx)))+(square(cx))))))*((ax)+(ax))
# PLUMED:     (0.5*(recip(sqrt(((square(ax))+(square(bx)))+(square(cx))))))*((bx)+(bx))
# PLUMED:     (0.5*(recip(sqrt(((square(ax))+(square(bx)))+(square(cx))))))*((cx)+(cx))
# PLUMED: Action METAD
# PLUMED:   with label metad
# PLUMED:   with arguments sumrmsdint
# PLUMED:   added component to this action:  metad.bias
# PLUMED:   Binsize not specified, 1/5 of sigma will be be used
# PLUMED:   Gaussian width  0.050000  Gaussian height 0.000000
# PLUMED:   Gaussian deposition pace 10000000
# PLUMED:   Gaussian file HILLS
# PLUMED:   Well-Tempered Bias Factor 2.000000
# PLUMED:   Hills relaxation time (tau) inf
# PLUMED:   KbT 2.577483
# PLUMED:   Grid min 0.0
# PLUMED:   Grid max 17.0
# PLUMED:   Grid bin 1700
# PLUMED:   Grid uses spline interpolation
# PLUMED:   Restarting from HILLS:      3392000 Gaussians read
# PLUMED:   Bibliography [3][4]
# PLUMED: Action REWEIGHT_BIAS
# PLUMED:   with label as
# PLUMED:   with arguments metad.bias
# PLUMED: Action HISTOGRAM
# PLUMED:   with label hhrmsda
# PLUMED:   with stride 1
# PLUMED:   with arguments sumrmsdint
# PLUMED:   reweighting using weights from as
# PLUMED:   grid of 341 equally spaced points between (0.0) and (17.0)
# PLUMED: Action CONVERT_TO_FES
# PLUMED:   with label ffrmsda
# PLUMED:   using 0th component of grid calculated by action hhrmsda
# PLUMED:   grid of 341 equally spaced points between (0.0) and (17.0)
# PLUMED: Action DUMPGRID
# PLUMED:   with label @8
# PLUMED:   with stride 0
# PLUMED:   outputting grid calculated by action ffrmsda to file named ffrmsda_reweighted.dat with format %f
# PLUMED:   outputting data for replicas 0 Action PRINT
# PLUMED:   with label @9
# PLUMED:   with stride 1
# PLUMED:   with arguments sumrmsdint metad.bias
# PLUMED:   on file COLVAR_reweighted
# PLUMED:   with format  %f
# PLUMED: END FILE: plumed_rew.dat
# PLUMED: Timestep: 10.000000
# PLUMED: KbT: 2.577483
# PLUMED: Relevant bibliography:
# PLUMED:   [1] The PLUMED consortium, Nat. Methods 16, 670 (2019)
# PLUMED:   [2] Tribello, Bonomi, Branduardi, Camilloni, and Bussi, Comput. Phys. Commun. 185, 604 (2014)
# PLUMED:   [3] Laio and Parrinello, PNAS 99, 12562 (2002)
# PLUMED:   [4] Barducci, Bussi, and Parrinello, Phys. Rev. Lett. 100, 020603 (2008)
# PLUMED: Please read and cite where appropriate!
# PLUMED: Finished setup
# PLUMED:                                               Cycles        Total      Average      Minimum      Maximum
# PLUMED:                                                    1   154.653392   154.653392   154.653392   154.653392
# PLUMED: 1 Prepare dependencies                        339201     0.220023     0.000001     0.000000     0.000019
# PLUMED: 2 Sharing data                                339201     5.962350     0.000018     0.000015     0.000229
# PLUMED: 3 Waiting for data                            339201     0.133816     0.000000     0.000000     0.000020
# PLUMED: 4 Calculating (forward loop)                  339201    39.463757     0.000116     0.000101     0.000558
# PLUMED: 5 Applying (backward loop)                    339201     7.432767     0.000022     0.000019     0.000101
# PLUMED: 6 Update                                      339201     6.300149     0.000019     0.000016     0.020164

# %%
data_colvar_rew=plumed.read_as_pandas("COLVAR_reweighted")

# %%
data_b=plumed.read_as_pandas("fes_169.dat")
data_r=plumed.read_as_pandas("ffrmsda_reweighted.dat")

# %%
plt.figure(figsize=(10,6))
plt.xlabel("sumrmsdint [nm]")
plt.ylabel("free energy [kJ/mol]")
plt.plot(data_b["sumrmsdint"],data_b["file.free"], label="sum_HILLS")
plt.plot(data_r["sumrmsdint"],data_r["ffrmsda"]-min(data_r["ffrmsda"]),label="Reweighting")
plt.legend()

# %%
plt.figure(figsize=(10,6))
plt.xlabel("sumrmsdint per chain [nm]")
plt.ylabel("free energy [kJ/mol]")
plt.plot(data_b["sumrmsdint"]/3,data_b["file.free"], label="sum_HILLS")
plt.plot(data_r["sumrmsdint"]/3,data_r["ffrmsda"]-min(data_r["ffrmsda"]),label="Reweighting")
plt.legend()

# %%
'''
# %%bash
gmx trjcat -f traj_comp_align.xtc -o traj1.0-2.0.xtc -b 1000000 -e 2000000 -dt 10.0
gmx trjcat -f traj_comp_align.xtc -o traj2.0-3.0.xtc -b 2000000 -e 3000000 -dt 10.0
'''
# Out:
# '\n%%bash\ngmx trjcat -f traj_comp_align.xtc -o traj1.0-2.0.xtc -b 1000000 -e 2000000 -dt 10.0\ngmx trjcat -f traj_comp_align.xtc -o traj2.0-3.0.xtc -b 2000000 -e 3000000 -dt 10.0\n'

# %%
p=plumed.Plumed()

# %%
myhills=plumed.read_as_pandas("HILLS") # first read hills file

# %%
plumed.hills_time_average(myhills,"HILLS1.0-2.0",t0=1000000,t1=2000000) # time average between 1000 and 2000 ns

# %%
plumed.hills_time_average(myhills,"HILLS2.0-3.0",t0=2000000,t1=3000000) # time average between 2000 and 3000 ns

# %%
# %%bash
# cat > "plumed_rew1.0-2.0.dat" << EOF
# rmsda: RMSD REFERENCE=prot_ref_a.pdb TYPE=OPTIMAL
# rmsdb: RMSD REFERENCE=prot_ref_b.pdb TYPE=OPTIMAL
# rmsdc: RMSD REFERENCE=prot_ref_c.pdb TYPE=OPTIMAL
# sumrmsdint: CUSTOM ARG=rmsda,rmsdb,rmsdc VAR=ax,bx,cx FUNC=sqrt(ax*ax+bx*bx+cx*cx) PERIODIC=NO
#
# metad: METAD ARG=sumrmsdint ...
# PACE=10000000 HEIGHT=0.0 SIGMA=0.05 FILE=HILLS1.0-2.0 GRID_MIN=0.0 GRID_MAX=17.0 BIASFACTOR=2.0 TEMP=310.0
# RESTART=YES # <- this is the new stuff!
# ...
#
# # Use the metadynamics bias as argument
# as: REWEIGHT_BIAS ARG=metad.bias
# # Calculate histograms of phi and psi dihedrals every 50 steps
# # using the weights obtained from the metadynamics bias potentials (umbrella-sampling-like reweighting)
# # Look at the manual to understand the parameters of the HISTOGRAM action!
# hhrmsda: HISTOGRAM ARG=sumrmsdint STRIDE=1 GRID_MIN=0.0 GRID_MAX=17.0 GRID_BIN=340 BANDWIDTH=0.05 LOGWEIGHTS=as
# # Convert histograms h(s) to free energies F(s) = -kBT * log(h(s))
# ffrmsda: CONVERT_TO_FES GRID=hhrmsda
# # Print out the free energies F(s) to file once the entire trajectory is processed
# DUMPGRID GRID=ffrmsda FILE=ffrmsda_reweighted1.0-2.0.dat
#
# PRINT ARG=sumrmsdint,metad.bias FILE=COLVAR_reweighted1.0-2.0 STRIDE=1 # <- also change this one!
# EOF

# %%
# %%bash
# gmx trjcat -f traj_comp_align.xtc -o traj1.0-2.0.xtc -b 1000000 -e 2000000 -dt 10.0
# gmx trjcat -f traj_comp_align.xtc -o traj2.0-3.0.xtc -b 2000000 -e 3000000 -dt 10.0
# Out:
# Note that major changes are planned in future for trjcat, to improve usability and utility.
# lasttime 0
# Note that major changes are planned in future for trjcat, to improve usability and utility.
# lasttime 0
#                :-) GROMACS - gmx trjcat, 2022.5-plumed_2.9.0 (-:
#
# Executable:   /opt/gromacs-2022.5/bin/gmx_mpi
# Data prefix:  /opt/gromacs-2022.5
# Working dir:  /hdnas/marcol/tau/polimeri-120/trimer/CV-meta4/select-new
# Command line:
#   gmx trjcat -f traj_comp_align.xtc -o traj1.0-2.0.xtc -b 1000000 -e 2000000 -dt 10.0
#
# Reading frame       1 time   10.000
#
# Summary of files and start times used:
#
#           File                Start time       Time step
# ---------------------------------------------------------
#       traj_comp_align.xtc        0.000 ps       10.000 ps
#
# Reading frame  100000 time 1000000.000
# Continue writing frames from traj_comp_align.xtc t=1e+06 ps, frame=0
# Reading frame  200000 time 2000000.000    ->  frame 100000 time 2000000.000 ps
# Last frame written was 100000, time 2000000.000000 ps
#
# GROMACS reminds you: "Wicky-wicky Wa-wild West" (Will Smith)
#
#                :-) GROMACS - gmx trjcat, 2022.5-plumed_2.9.0 (-:
#
# Executable:   /opt/gromacs-2022.5/bin/gmx_mpi
# Data prefix:  /opt/gromacs-2022.5
# Working dir:  /hdnas/marcol/tau/polimeri-120/trimer/CV-meta4/select-new
# Command line:
#   gmx trjcat -f traj_comp_align.xtc -o traj2.0-3.0.xtc -b 2000000 -e 3000000 -dt 10.0
#
# Reading frame       1 time   10.000
#
# Summary of files and start times used:
#
#           File                Start time       Time step
# ---------------------------------------------------------
#       traj_comp_align.xtc        0.000 ps       10.000 ps
#
# Reading frame  200000 time 2000000.000
# Continue writing frames from traj_comp_align.xtc t=2e+06 ps, frame=0
# Reading frame  300000 time 3000000.000    ->  frame 100000 time 3000000.000 ps
# Last frame written was 100000, time 3000000.000000 ps
#
# GROMACS reminds you: "I'm Not Gonna Die Here !" (Sphere)

# %%
'''
plumed driver --ixtc traj1.0-2.0.xtc --plumed plumed_rew1.0-2.0.dat --kt 2.57748341158 --timestep 10.0
'''
# Out:
# '\nplumed driver --ixtc traj1.0-2.0.xtc --plumed plumed_rew1.0-2.0.dat --kt 2.57748341158 --timestep 10.0\n'

# %%
# %%bash
# plumed driver --ixtc traj1.0-2.0.xtc --plumed plumed_rew1.0-2.0.dat --kt 2.57748341158 --timestep 10.0
# Out:
# PLUMED: PLUMED is starting
# PLUMED: Version: 2.9.0 (git: Unknown) compiled on Jun 18 2023 at 17:13:44
# PLUMED: Please cite these papers when using PLUMED [1][2]
# PLUMED: For further information see the PLUMED web page at http://www.plumed.org
# PLUMED: Root: /opt/plumed-2.9.0/lib/plumed
# PLUMED: For installed feature, see /opt/plumed-2.9.0/lib/plumed/src/config/config.txt
# PLUMED: Molecular dynamics engine: driver
# PLUMED: Precision of reals: 8
# PLUMED: Running over 1 node
# PLUMED: Number of threads: 1
# PLUMED: Cache line size: 512
# PLUMED: Number of atoms: 3591
# PLUMED: File suffix:
# PLUMED: FILE: plumed_rew1.0-2.0.dat
# PLUMED: Action RMSD
# PLUMED:   with label rmsda
# PLUMED:   reference from file prot_ref_a.pdb
# PLUMED:   which contains 307 atoms
# PLUMED:   with indices :
# PLUMED: 1 5 8 9 10 12 19 20 21 23 35 36 37 39 52 53 54 56 71 72 73 75 87 88 89
# PLUMED: 91 108 109 110 112 130 131 132 136 144 145 146 148 160 161 162 164 172 173 174 176 191 192 193 195
# PLUMED: 202 203 204 206 224 225 226 228 240 241 242 244 254 255 256 258 265 266 267 269 287 288 289 291 298
# PLUMED: 299 300 302 305 306 307 309 316 317 318 320 335 336 337 339 342 343 344 346 356 357 358 360 375 376
# PLUMED: 377 379 392 393 394 396 409 410 411 413 431 432 433 437 445 446 447 449 452 453 454 456 459 460 461
# PLUMED: 463 466 467 468 470 483 484 485 487 499 500 501 503 514 515 516 518 530 531 532 534 552 553 554 556
# PLUMED: 563 564 565 567 578 579 580 582 600 601 602 604 619 620 621 623 631 632 633 635 651 652 653 655 673
# PLUMED: 674 675 677 685 686 687 689 709 710 711 713 725 726 727 729 742 743 744 746 753 754 755 757 775 776
# PLUMED: 777 779 794 795 796 798 801 802 803 805 812 813 814 816 831 832 833 835 843 844 845 847 857 858 859
# PLUMED: 861 876 877 878 880 890 891 892 894 907 908 909 911 923 924 925 929 937 938 939 941 944 945 946 948
# PLUMED: 951 952 953 955 958 959 960 962 972 973 974 976 994 995 996 998 1016 1017 1018 1020 1035 1036 1037 1039 1050
# PLUMED: 1051 1052 1054 1064 1065 1066 1068 1081 1082 1083 1085 1103 1104 1105 1107 1122 1123 1124 1126 1136 1137 1138 1140 1156 1157
# PLUMED: 1158 1160 1180 1181 1182 1184 1195
# PLUMED:   method for alignment : OPTIMAL
# PLUMED:   using periodic boundary conditions
# PLUMED: Action RMSD
# PLUMED:   with label rmsdb
# PLUMED:   reference from file prot_ref_b.pdb
# PLUMED:   which contains 307 atoms
# PLUMED:   with indices :
# PLUMED: 1198 1202 1205 1206 1207 1209 1216 1217 1218 1220 1232 1233 1234 1236 1249 1250 1251 1253 1268 1269 1270 1272 1284 1285 1286
# PLUMED: 1288 1305 1306 1307 1309 1327 1328 1329 1333 1341 1342 1343 1345 1357 1358 1359 1361 1369 1370 1371 1373 1388 1389 1390 1392
# PLUMED: 1399 1400 1401 1403 1421 1422 1423 1425 1437 1438 1439 1441 1451 1452 1453 1455 1462 1463 1464 1466 1484 1485 1486 1488 1495
# PLUMED: 1496 1497 1499 1502 1503 1504 1506 1513 1514 1515 1517 1532 1533 1534 1536 1539 1540 1541 1543 1553 1554 1555 1557 1572 1573
# PLUMED: 1574 1576 1589 1590 1591 1593 1606 1607 1608 1610 1628 1629 1630 1634 1642 1643 1644 1646 1649 1650 1651 1653 1656 1657 1658
# PLUMED: 1660 1663 1664 1665 1667 1680 1681 1682 1684 1696 1697 1698 1700 1711 1712 1713 1715 1727 1728 1729 1731 1749 1750 1751 1753
# PLUMED: 1760 1761 1762 1764 1775 1776 1777 1779 1797 1798 1799 1801 1816 1817 1818 1820 1828 1829 1830 1832 1848 1849 1850 1852 1870
# PLUMED: 1871 1872 1874 1882 1883 1884 1886 1906 1907 1908 1910 1922 1923 1924 1926 1939 1940 1941 1943 1950 1951 1952 1954 1972 1973
# PLUMED: 1974 1976 1991 1992 1993 1995 1998 1999 2000 2002 2009 2010 2011 2013 2028 2029 2030 2032 2040 2041 2042 2044 2054 2055 2056
# PLUMED: 2058 2073 2074 2075 2077 2087 2088 2089 2091 2104 2105 2106 2108 2120 2121 2122 2126 2134 2135 2136 2138 2141 2142 2143 2145
# PLUMED: 2148 2149 2150 2152 2155 2156 2157 2159 2169 2170 2171 2173 2191 2192 2193 2195 2213 2214 2215 2217 2232 2233 2234 2236 2247
# PLUMED: 2248 2249 2251 2261 2262 2263 2265 2278 2279 2280 2282 2300 2301 2302 2304 2319 2320 2321 2323 2333 2334 2335 2337 2353 2354
# PLUMED: 2355 2357 2377 2378 2379 2381 2392
# PLUMED:   method for alignment : OPTIMAL
# PLUMED:   using periodic boundary conditions
# PLUMED: Action RMSD
# PLUMED:   with label rmsdc
# PLUMED:   reference from file prot_ref_c.pdb
# PLUMED:   which contains 307 atoms
# PLUMED:   with indices :
# PLUMED: 2395 2399 2402 2403 2404 2406 2413 2414 2415 2417 2429 2430 2431 2433 2446 2447 2448 2450 2465 2466 2467 2469 2481 2482 2483
# PLUMED: 2485 2502 2503 2504 2506 2524 2525 2526 2530 2538 2539 2540 2542 2554 2555 2556 2558 2566 2567 2568 2570 2585 2586 2587 2589
# PLUMED: 2596 2597 2598 2600 2618 2619 2620 2622 2634 2635 2636 2638 2648 2649 2650 2652 2659 2660 2661 2663 2681 2682 2683 2685 2692
# PLUMED: 2693 2694 2696 2699 2700 2701 2703 2710 2711 2712 2714 2729 2730 2731 2733 2736 2737 2738 2740 2750 2751 2752 2754 2769 2770
# PLUMED: 2771 2773 2786 2787 2788 2790 2803 2804 2805 2807 2825 2826 2827 2831 2839 2840 2841 2843 2846 2847 2848 2850 2853 2854 2855
# PLUMED: 2857 2860 2861 2862 2864 2877 2878 2879 2881 2893 2894 2895 2897 2908 2909 2910 2912 2924 2925 2926 2928 2946 2947 2948 2950
# PLUMED: 2957 2958 2959 2961 2972 2973 2974 2976 2994 2995 2996 2998 3013 3014 3015 3017 3025 3026 3027 3029 3045 3046 3047 3049 3067
# PLUMED: 3068 3069 3071 3079 3080 3081 3083 3103 3104 3105 3107 3119 3120 3121 3123 3136 3137 3138 3140 3147 3148 3149 3151 3169 3170
# PLUMED: 3171 3173 3188 3189 3190 3192 3195 3196 3197 3199 3206 3207 3208 3210 3225 3226 3227 3229 3237 3238 3239 3241 3251 3252 3253
# PLUMED: 3255 3270 3271 3272 3274 3284 3285 3286 3288 3301 3302 3303 3305 3317 3318 3319 3323 3331 3332 3333 3335 3338 3339 3340 3342
# PLUMED: 3345 3346 3347 3349 3352 3353 3354 3356 3366 3367 3368 3370 3388 3389 3390 3392 3410 3411 3412 3414 3429 3430 3431 3433 3444
# PLUMED: 3445 3446 3448 3458 3459 3460 3462 3475 3476 3477 3479 3497 3498 3499 3501 3516 3517 3518 3520 3530 3531 3532 3534 3550 3551
# PLUMED: 3552 3554 3574 3575 3576 3578 3589
# PLUMED:   method for alignment : OPTIMAL
# PLUMED:   using periodic boundary conditions
# PLUMED: Action CUSTOM
# PLUMED:   with label sumrmsdint
# PLUMED:   with arguments rmsda rmsdb rmsdc
# PLUMED:   with function : sqrt(ax*ax+bx*bx+cx*cx)
# PLUMED:   with variables : ax bx cx
# PLUMED:   function as parsed by lepton: sqrt(((square(ax))+(square(bx)))+(square(cx)))
# PLUMED:   derivatives as computed by lepton:
# PLUMED:     (0.5*(recip(sqrt(((square(ax))+(square(bx)))+(square(cx))))))*((ax)+(ax))
# PLUMED:     (0.5*(recip(sqrt(((square(ax))+(square(bx)))+(square(cx))))))*((bx)+(bx))
# PLUMED:     (0.5*(recip(sqrt(((square(ax))+(square(bx)))+(square(cx))))))*((cx)+(cx))
# PLUMED: Action METAD
# PLUMED:   with label metad
# PLUMED:   with arguments sumrmsdint
# PLUMED:   added component to this action:  metad.bias
# PLUMED:   Binsize not specified, 1/5 of sigma will be be used
# PLUMED:   Gaussian width  0.050000  Gaussian height 0.000000
# PLUMED:   Gaussian deposition pace 10000000
# PLUMED:   Gaussian file HILLS1.0-2.0
# PLUMED:   Well-Tempered Bias Factor 2.000000
# PLUMED:   Hills relaxation time (tau) inf
# PLUMED:   KbT 2.577483
# PLUMED:   Grid min 0.0
# PLUMED:   Grid max 17.0
# PLUMED:   Grid bin 1700
# PLUMED:   Grid uses spline interpolation
# PLUMED:   Restarting from HILLS1.0-2.0:      3392000 Gaussians read
# PLUMED:   Bibliography [3][4]
# PLUMED: Action REWEIGHT_BIAS
# PLUMED:   with label as
# PLUMED:   with arguments metad.bias
# PLUMED: Action HISTOGRAM
# PLUMED:   with label hhrmsda
# PLUMED:   with stride 1
# PLUMED:   with arguments sumrmsdint
# PLUMED:   reweighting using weights from as
# PLUMED:   grid of 341 equally spaced points between (0.0) and (17.0)
# PLUMED: Action CONVERT_TO_FES
# PLUMED:   with label ffrmsda
# PLUMED:   using 0th component of grid calculated by action hhrmsda
# PLUMED:   grid of 341 equally spaced points between (0.0) and (17.0)
# PLUMED: Action DUMPGRID
# PLUMED:   with label @8
# PLUMED:   with stride 0
# PLUMED:   outputting grid calculated by action ffrmsda to file named ffrmsda_reweighted1.0-2.0.dat with format %f
# PLUMED:   outputting data for replicas 0 Action PRINT
# PLUMED:   with label @9
# PLUMED:   with stride 1
# PLUMED:   with arguments sumrmsdint metad.bias
# PLUMED:   on file COLVAR_reweighted1.0-2.0
# PLUMED:   with format  %f
# PLUMED: END FILE: plumed_rew1.0-2.0.dat
# PLUMED: Timestep: 10.000000
# PLUMED: KbT: 2.577483
# PLUMED: Relevant bibliography:
# PLUMED:   [1] The PLUMED consortium, Nat. Methods 16, 670 (2019)
# PLUMED:   [2] Tribello, Bonomi, Branduardi, Camilloni, and Bussi, Comput. Phys. Commun. 185, 604 (2014)
# PLUMED:   [3] Laio and Parrinello, PNAS 99, 12562 (2002)
# PLUMED:   [4] Barducci, Bussi, and Parrinello, Phys. Rev. Lett. 100, 020603 (2008)
# PLUMED: Please read and cite where appropriate!
# PLUMED: Finished setup
# PLUMED:                                               Cycles        Total      Average      Minimum      Maximum
# PLUMED:                                                    1    87.771954    87.771954    87.771954    87.771954
# PLUMED: 1 Prepare dependencies                        100001     0.065070     0.000001     0.000000     0.000021
# PLUMED: 2 Sharing data                                100001     1.742214     0.000017     0.000015     0.000456
# PLUMED: 3 Waiting for data                            100001     0.033449     0.000000     0.000000     0.000019
# PLUMED: 4 Calculating (forward loop)                  100001    11.563005     0.000116     0.000102     0.000709
# PLUMED: 5 Applying (backward loop)                    100001     2.194033     0.000022     0.000019     0.000109
# PLUMED: 6 Update                                      100001     1.820888     0.000018     0.000016     0.000785

# %%
# %%bash
# cat > "plumed_rew2.0-3.0.dat" << EOF
#
# rmsda: RMSD REFERENCE=prot_ref_a.pdb TYPE=OPTIMAL
# rmsdb: RMSD REFERENCE=prot_ref_b.pdb TYPE=OPTIMAL
# rmsdc: RMSD REFERENCE=prot_ref_c.pdb TYPE=OPTIMAL
# sumrmsdint: CUSTOM ARG=rmsda,rmsdb,rmsdc VAR=ax,bx,cx FUNC=sqrt(ax*ax+bx*bx+cx*cx) PERIODIC=NO
#
# metad: METAD ARG=sumrmsdint ...
# PACE=10000000 HEIGHT=0.0 SIGMA=0.05 FILE=HILLS2.0-3.0 GRID_MIN=0.0 GRID_MAX=17.0 BIASFACTOR=2.0 TEMP=310.0
# RESTART=YES # <- this is the new stuff!
# ...
#
# # Use the metadynamics bias as argument
# as: REWEIGHT_BIAS ARG=metad.bias
# # Calculate histograms of phi and psi dihedrals every 50 steps
# # using the weights obtained from the metadynamics bias potentials (umbrella-sampling-like reweighting)
# # Look at the manual to understand the parameters of the HISTOGRAM action!
# hhrmsda: HISTOGRAM ARG=sumrmsdint STRIDE=1 GRID_MIN=0.0 GRID_MAX=17.0 GRID_BIN=340 BANDWIDTH=0.05 LOGWEIGHTS=as
# # Convert histograms h(s) to free energies F(s) = -kBT * log(h(s))
# ffrmsda: CONVERT_TO_FES GRID=hhrmsda
# # Print out the free energies F(s) to file once the entire trajectory is processed
# DUMPGRID GRID=ffrmsda FILE=ffrmsda_reweighted2.0-3.0.dat
#
# PRINT ARG=sumrmsdint,metad.bias FILE=COLVAR_reweighted2.0-3.0 STRIDE=1 # <- also change this one!
#
# EOF

# %%
'''
plumed driver --ixtc traj2.0-3.0.xtc --plumed plumed_rew2.0-3.0.dat --kt 2.57748341158 --timestep 10.0
'''
# Out:
# '\nplumed driver --ixtc traj2.0-3.0.xtc --plumed plumed_rew2.0-3.0.dat --kt 2.57748341158 --timestep 10.0\n'

# %%
# %%bash
# plumed driver --ixtc traj2.0-3.0.xtc --plumed plumed_rew2.0-3.0.dat --kt 2.57748341158 --timestep 10.0
# Out:
# PLUMED: PLUMED is starting
# PLUMED: Version: 2.9.0 (git: Unknown) compiled on Jun 18 2023 at 17:13:44
# PLUMED: Please cite these papers when using PLUMED [1][2]
# PLUMED: For further information see the PLUMED web page at http://www.plumed.org
# PLUMED: Root: /opt/plumed-2.9.0/lib/plumed
# PLUMED: For installed feature, see /opt/plumed-2.9.0/lib/plumed/src/config/config.txt
# PLUMED: Molecular dynamics engine: driver
# PLUMED: Precision of reals: 8
# PLUMED: Running over 1 node
# PLUMED: Number of threads: 1
# PLUMED: Cache line size: 512
# PLUMED: Number of atoms: 3591
# PLUMED: File suffix:
# PLUMED: FILE: plumed_rew2.0-3.0.dat
# PLUMED: Action RMSD
# PLUMED:   with label rmsda
# PLUMED:   reference from file prot_ref_a.pdb
# PLUMED:   which contains 307 atoms
# PLUMED:   with indices :
# PLUMED: 1 5 8 9 10 12 19 20 21 23 35 36 37 39 52 53 54 56 71 72 73 75 87 88 89
# PLUMED: 91 108 109 110 112 130 131 132 136 144 145 146 148 160 161 162 164 172 173 174 176 191 192 193 195
# PLUMED: 202 203 204 206 224 225 226 228 240 241 242 244 254 255 256 258 265 266 267 269 287 288 289 291 298
# PLUMED: 299 300 302 305 306 307 309 316 317 318 320 335 336 337 339 342 343 344 346 356 357 358 360 375 376
# PLUMED: 377 379 392 393 394 396 409 410 411 413 431 432 433 437 445 446 447 449 452 453 454 456 459 460 461
# PLUMED: 463 466 467 468 470 483 484 485 487 499 500 501 503 514 515 516 518 530 531 532 534 552 553 554 556
# PLUMED: 563 564 565 567 578 579 580 582 600 601 602 604 619 620 621 623 631 632 633 635 651 652 653 655 673
# PLUMED: 674 675 677 685 686 687 689 709 710 711 713 725 726 727 729 742 743 744 746 753 754 755 757 775 776
# PLUMED: 777 779 794 795 796 798 801 802 803 805 812 813 814 816 831 832 833 835 843 844 845 847 857 858 859
# PLUMED: 861 876 877 878 880 890 891 892 894 907 908 909 911 923 924 925 929 937 938 939 941 944 945 946 948
# PLUMED: 951 952 953 955 958 959 960 962 972 973 974 976 994 995 996 998 1016 1017 1018 1020 1035 1036 1037 1039 1050
# PLUMED: 1051 1052 1054 1064 1065 1066 1068 1081 1082 1083 1085 1103 1104 1105 1107 1122 1123 1124 1126 1136 1137 1138 1140 1156 1157
# PLUMED: 1158 1160 1180 1181 1182 1184 1195
# PLUMED:   method for alignment : OPTIMAL
# PLUMED:   using periodic boundary conditions
# PLUMED: Action RMSD
# PLUMED:   with label rmsdb
# PLUMED:   reference from file prot_ref_b.pdb
# PLUMED:   which contains 307 atoms
# PLUMED:   with indices :
# PLUMED: 1198 1202 1205 1206 1207 1209 1216 1217 1218 1220 1232 1233 1234 1236 1249 1250 1251 1253 1268 1269 1270 1272 1284 1285 1286
# PLUMED: 1288 1305 1306 1307 1309 1327 1328 1329 1333 1341 1342 1343 1345 1357 1358 1359 1361 1369 1370 1371 1373 1388 1389 1390 1392
# PLUMED: 1399 1400 1401 1403 1421 1422 1423 1425 1437 1438 1439 1441 1451 1452 1453 1455 1462 1463 1464 1466 1484 1485 1486 1488 1495
# PLUMED: 1496 1497 1499 1502 1503 1504 1506 1513 1514 1515 1517 1532 1533 1534 1536 1539 1540 1541 1543 1553 1554 1555 1557 1572 1573
# PLUMED: 1574 1576 1589 1590 1591 1593 1606 1607 1608 1610 1628 1629 1630 1634 1642 1643 1644 1646 1649 1650 1651 1653 1656 1657 1658
# PLUMED: 1660 1663 1664 1665 1667 1680 1681 1682 1684 1696 1697 1698 1700 1711 1712 1713 1715 1727 1728 1729 1731 1749 1750 1751 1753
# PLUMED: 1760 1761 1762 1764 1775 1776 1777 1779 1797 1798 1799 1801 1816 1817 1818 1820 1828 1829 1830 1832 1848 1849 1850 1852 1870
# PLUMED: 1871 1872 1874 1882 1883 1884 1886 1906 1907 1908 1910 1922 1923 1924 1926 1939 1940 1941 1943 1950 1951 1952 1954 1972 1973
# PLUMED: 1974 1976 1991 1992 1993 1995 1998 1999 2000 2002 2009 2010 2011 2013 2028 2029 2030 2032 2040 2041 2042 2044 2054 2055 2056
# PLUMED: 2058 2073 2074 2075 2077 2087 2088 2089 2091 2104 2105 2106 2108 2120 2121 2122 2126 2134 2135 2136 2138 2141 2142 2143 2145
# PLUMED: 2148 2149 2150 2152 2155 2156 2157 2159 2169 2170 2171 2173 2191 2192 2193 2195 2213 2214 2215 2217 2232 2233 2234 2236 2247
# PLUMED: 2248 2249 2251 2261 2262 2263 2265 2278 2279 2280 2282 2300 2301 2302 2304 2319 2320 2321 2323 2333 2334 2335 2337 2353 2354
# PLUMED: 2355 2357 2377 2378 2379 2381 2392
# PLUMED:   method for alignment : OPTIMAL
# PLUMED:   using periodic boundary conditions
# PLUMED: Action RMSD
# PLUMED:   with label rmsdc
# PLUMED:   reference from file prot_ref_c.pdb
# PLUMED:   which contains 307 atoms
# PLUMED:   with indices :
# PLUMED: 2395 2399 2402 2403 2404 2406 2413 2414 2415 2417 2429 2430 2431 2433 2446 2447 2448 2450 2465 2466 2467 2469 2481 2482 2483
# PLUMED: 2485 2502 2503 2504 2506 2524 2525 2526 2530 2538 2539 2540 2542 2554 2555 2556 2558 2566 2567 2568 2570 2585 2586 2587 2589
# PLUMED: 2596 2597 2598 2600 2618 2619 2620 2622 2634 2635 2636 2638 2648 2649 2650 2652 2659 2660 2661 2663 2681 2682 2683 2685 2692
# PLUMED: 2693 2694 2696 2699 2700 2701 2703 2710 2711 2712 2714 2729 2730 2731 2733 2736 2737 2738 2740 2750 2751 2752 2754 2769 2770
# PLUMED: 2771 2773 2786 2787 2788 2790 2803 2804 2805 2807 2825 2826 2827 2831 2839 2840 2841 2843 2846 2847 2848 2850 2853 2854 2855
# PLUMED: 2857 2860 2861 2862 2864 2877 2878 2879 2881 2893 2894 2895 2897 2908 2909 2910 2912 2924 2925 2926 2928 2946 2947 2948 2950
# PLUMED: 2957 2958 2959 2961 2972 2973 2974 2976 2994 2995 2996 2998 3013 3014 3015 3017 3025 3026 3027 3029 3045 3046 3047 3049 3067
# PLUMED: 3068 3069 3071 3079 3080 3081 3083 3103 3104 3105 3107 3119 3120 3121 3123 3136 3137 3138 3140 3147 3148 3149 3151 3169 3170
# PLUMED: 3171 3173 3188 3189 3190 3192 3195 3196 3197 3199 3206 3207 3208 3210 3225 3226 3227 3229 3237 3238 3239 3241 3251 3252 3253
# PLUMED: 3255 3270 3271 3272 3274 3284 3285 3286 3288 3301 3302 3303 3305 3317 3318 3319 3323 3331 3332 3333 3335 3338 3339 3340 3342
# PLUMED: 3345 3346 3347 3349 3352 3353 3354 3356 3366 3367 3368 3370 3388 3389 3390 3392 3410 3411 3412 3414 3429 3430 3431 3433 3444
# PLUMED: 3445 3446 3448 3458 3459 3460 3462 3475 3476 3477 3479 3497 3498 3499 3501 3516 3517 3518 3520 3530 3531 3532 3534 3550 3551
# PLUMED: 3552 3554 3574 3575 3576 3578 3589
# PLUMED:   method for alignment : OPTIMAL
# PLUMED:   using periodic boundary conditions
# PLUMED: Action CUSTOM
# PLUMED:   with label sumrmsdint
# PLUMED:   with arguments rmsda rmsdb rmsdc
# PLUMED:   with function : sqrt(ax*ax+bx*bx+cx*cx)
# PLUMED:   with variables : ax bx cx
# PLUMED:   function as parsed by lepton: sqrt(((square(ax))+(square(bx)))+(square(cx)))
# PLUMED:   derivatives as computed by lepton:
# PLUMED:     (0.5*(recip(sqrt(((square(ax))+(square(bx)))+(square(cx))))))*((ax)+(ax))
# PLUMED:     (0.5*(recip(sqrt(((square(ax))+(square(bx)))+(square(cx))))))*((bx)+(bx))
# PLUMED:     (0.5*(recip(sqrt(((square(ax))+(square(bx)))+(square(cx))))))*((cx)+(cx))
# PLUMED: Action METAD
# PLUMED:   with label metad
# PLUMED:   with arguments sumrmsdint
# PLUMED:   added component to this action:  metad.bias
# PLUMED:   Binsize not specified, 1/5 of sigma will be be used
# PLUMED:   Gaussian width  0.050000  Gaussian height 0.000000
# PLUMED:   Gaussian deposition pace 10000000
# PLUMED:   Gaussian file HILLS2.0-3.0
# PLUMED:   Well-Tempered Bias Factor 2.000000
# PLUMED:   Hills relaxation time (tau) inf
# PLUMED:   KbT 2.577483
# PLUMED:   Grid min 0.0
# PLUMED:   Grid max 17.0
# PLUMED:   Grid bin 1700
# PLUMED:   Grid uses spline interpolation
# PLUMED:   Restarting from HILLS2.0-3.0:      3392000 Gaussians read
# PLUMED:   Bibliography [3][4]
# PLUMED: Action REWEIGHT_BIAS
# PLUMED:   with label as
# PLUMED:   with arguments metad.bias
# PLUMED: Action HISTOGRAM
# PLUMED:   with label hhrmsda
# PLUMED:   with stride 1
# PLUMED:   with arguments sumrmsdint
# PLUMED:   reweighting using weights from as
# PLUMED:   grid of 341 equally spaced points between (0.0) and (17.0)
# PLUMED: Action CONVERT_TO_FES
# PLUMED:   with label ffrmsda
# PLUMED:   using 0th component of grid calculated by action hhrmsda
# PLUMED:   grid of 341 equally spaced points between (0.0) and (17.0)
# PLUMED: Action DUMPGRID
# PLUMED:   with label @8
# PLUMED:   with stride 0
# PLUMED:   outputting grid calculated by action ffrmsda to file named ffrmsda_reweighted2.0-3.0.dat with format %f
# PLUMED:   outputting data for replicas 0 Action PRINT
# PLUMED:   with label @9
# PLUMED:   with stride 1
# PLUMED:   with arguments sumrmsdint metad.bias
# PLUMED:   on file COLVAR_reweighted2.0-3.0
# PLUMED:   with format  %f
# PLUMED: END FILE: plumed_rew2.0-3.0.dat
# PLUMED: Timestep: 10.000000
# PLUMED: KbT: 2.577483
# PLUMED: Relevant bibliography:
# PLUMED:   [1] The PLUMED consortium, Nat. Methods 16, 670 (2019)
# PLUMED:   [2] Tribello, Bonomi, Branduardi, Camilloni, and Bussi, Comput. Phys. Commun. 185, 604 (2014)
# PLUMED:   [3] Laio and Parrinello, PNAS 99, 12562 (2002)
# PLUMED:   [4] Barducci, Bussi, and Parrinello, Phys. Rev. Lett. 100, 020603 (2008)
# PLUMED: Please read and cite where appropriate!
# PLUMED: Finished setup
# PLUMED:                                               Cycles        Total      Average      Minimum      Maximum
# PLUMED:                                                    1    89.477479    89.477479    89.477479    89.477479
# PLUMED: 1 Prepare dependencies                        100001     0.077899     0.000001     0.000001     0.000021
# PLUMED: 2 Sharing data                                100001     1.742905     0.000017     0.000015     0.000470
# PLUMED: 3 Waiting for data                            100001     0.032471     0.000000     0.000000     0.000017
# PLUMED: 4 Calculating (forward loop)                  100001    11.438178     0.000114     0.000100     0.000722
# PLUMED: 5 Applying (backward loop)                    100001     2.184214     0.000022     0.000019     0.000057
# PLUMED: 6 Update                                      100001     1.851885     0.000019     0.000016     0.015677

# %%
data_r1_2=plumed.read_as_pandas("ffrmsda_reweighted1.0-2.0.dat")
data_r2_3=plumed.read_as_pandas("ffrmsda_reweighted2.0-3.0.dat")

# %%
plt.figure(figsize=(10,6))
plt.xlabel("sumrmsdint [nm]")
plt.ylabel("free energy [kJ/mol]")
plt.plot(data_b["sumrmsdint"],data_b["file.free"], label="sum_HILLS")
plt.plot(data_r["sumrmsdint"],data_r["ffrmsda"]-min(data_r["ffrmsda"]),label="Reweighting")
plt.plot(data_r1_2["sumrmsdint"],data_r1_2["ffrmsda"]-min(data_r1_2["ffrmsda"]),label="Reweighting_1.0_2.0")
plt.plot(data_r2_3["sumrmsdint"],data_r2_3["ffrmsda"]-min(data_r2_3["ffrmsda"]),label="Reweighting_2.0_3.0")
plt.axhline(y = 15.42, color = 'r', linestyle = 'dashed', label = "6 kbT")   
#plt.ylim([0, 20])
plt.legend()

# %%
plt.figure(figsize=(10,6))
plt.xlabel("sumrmsdint per chain [nm]")
plt.ylabel("free energy [kJ/mol]")
plt.plot(data_b["sumrmsdint"]/3,data_b["file.free"], label="sum_HILLS")
plt.plot(data_r["sumrmsdint"]/3,data_r["ffrmsda"]-min(data_r["ffrmsda"]),label="Reweighting")
plt.plot(data_r1_2["sumrmsdint"]/3,data_r1_2["ffrmsda"]-min(data_r1_2["ffrmsda"]),label="Reweighting_1.0_2.0")
plt.plot(data_r2_3["sumrmsdint"]/3,data_r2_3["ffrmsda"]-min(data_r2_3["ffrmsda"]),label="Reweighting_2.0_3.0")
plt.axhline(y = 15.42, color = 'r', linestyle = 'dashed', label = "6 kbT")   
#plt.ylim([0, 20])
plt.legend()
